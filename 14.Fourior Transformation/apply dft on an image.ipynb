# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">What is Fourier Transformation?</p>

# %% [markdown]
# <div style="margin:0 130px 0 30px;text-align:justify"><p style="font-family:Source Sans Pro;font-size:20px">The Fourier Transform is a mathematical operation that transforms a function of time (or space) into a function of frequency. In simpler terms, it decomposes a signal into its constituent frequencies, helping us understand how much of each frequency is present in the original signal.<br>
#  Purpose: <br>
#  It is used to analyze the frequency components of signals in various fields such as engineering, physics, and applied mathematics.</p></div>

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Mathematical Definition</p>

# %% [markdown]
# <div style="margin:0 130px 0 30px;text-align:justify"><p style="font-family:Source Sans Pro;font-size:20px"> For a continuous function f(x) the Fourier Transform F(∈) is defined as:</p></div>

# %% [markdown]
# <img src="../images-videos/FT.jpg" width="400" height="300"></img>

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Import Libraries</p>

# %%
import sys
sys.path.append('D:\\Image-Processing-Masterclass\\images-videos')
import createImg
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Initial Variables</p>

# %%
h = 200
w = 200
angle = -45
r = 20

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply Fourier Transformation</p>

# %%
def apply_dft(gray_img):
    dft = cv2.dft(np.float32(gray_img), flags=cv2.DFT_COMPLEX_OUTPUT)
    dft_shift = np.fft.fftshift(dft)
    epsilon = 1e-10
    magnitude_spectrum = 20 * (np.log10(cv2.magnitude(dft_shift[:, :, 0], dft_shift[:, :, 1]) + epsilon))
    magnitude_spectrum = cv2.normalize(magnitude_spectrum, None, 0, 255, cv2.NORM_MINMAX)
    return np.uint8(magnitude_spectrum)

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on vertical zeros</p>

# %%
img1 = createImg.v_sin_zeros()
img01 = apply_dft(img1)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img1, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img01, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on horizontal zeros</p>

# %%
img2 = createImg.h_sin_zeros()
img02 = apply_dft(img2)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img2, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img02, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on hatched zeros</p>

# %%
img3 = createImg.hatched_sin_zeros(angle)
img03 = apply_dft(img3)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img3, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img03, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on hatched circle</p>

# %%
img4 = createImg.hatched_sin_circle(angle, r)
img04 = apply_dft(img4)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img4, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img04, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on white circle</p>

# %%
img5 = createImg.whiteCircle(h, w, 12)
img5 = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
img05 = apply_dft(img5)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img5, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img05, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on white square</p>

# %%
img6 = createImg.whiteSquare(h, w)
img6 = cv2.cvtColor(img6, cv2.COLOR_BGR2GRAY)
img06 = apply_dft(img6)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img6, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img06, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on image</p>

# %%
img = cv2.imread('../images-videos/lenna.jpg')
img_gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_dft = apply_dft(img_gry)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img_gry, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_dft, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <p style="font-family:Bookman Old Style;font-size:27px; text-align:center">Apply DFT on other image</p>

# %%
img = cv2.imread('../images-videos/phone.jpg')
img_gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_dft = apply_dft(img_gry)

plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img_gry, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_dft, cmap='gray')
plt.axis('off')
plt.show()
